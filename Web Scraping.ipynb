# %%
import requests
from bs4 import BeautifulSoup

r = requests.get("https://pythonizing.github.io/data/real-estate/rock-springs-wy/LCWYROCKSPRINGS/", headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})
c=r.content

soup=BeautifulSoup(c,"html.parser")

all=soup.find_all("div",{"class":"propertyRow"})

all[0].find("h4",{"class":"propPrice"}).text.replace("\n","").replace(" ","")

page_num=soup.find_all("a",{"class":"Page"})[-1].text
print(page_num)
# Out:
# 3

# %%
l=[]
base_url="https://pythonizing.github.io/data/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s="
for i in range(0,int(page_num)*10,10):
    print(base_url+str(i)+".html")
    r=requests.get(base_url+str(i)+".html")
    c=r.content
    soup=BeautifulSoup(c,"html.parser")
    all=soup.find_all("div",{"class":"propertyRow"})
    for item in all:
        d={}
        d["Address"]=item.find_all("span",{"class":"propAddressCollapse"})[0].text
        try:
            d["Locality"]=item.find_all("span",{"class":"propAddressCollapse"})[1].text
        except:
            d["Locality"]=None
        try:
            d["Beds"]=item.find("span",{"class":"infoBed"}).find("b").text
        except:
            d["Beds"]=None
        try:
            d["Area"]=item.find("span",{"class":"infoSqFt"}).find("b").text
        except:
            d["Area"]=None
        try:
            d["Full Bath"]=item.find("span",{"class":"infoValueFullBath"}).find("b").text
        except:
            d["Full Bath"]=None
        try:
            d["Half Bath"]=item.find("span",{"class":"infoValueHalfBath"}).find("b").text
        except:
            d["Half Bath"]=None

        for column_group in item.find_all("div",{"class":"columnGroup"}):
            for feature_group,feature_name in zip(column_group.find_all("span",{"class":"featureGroup"}),column_group.find_all("span",{"class":"featureName"})):
                if "Lot Size" in feature_group.text:
                    d["Lot Size"]=feature_name.text
                    
        d["Price"]=item.find("h4",{"class":"propPrice"}).text.replace("\n","").replace(" ","")
        l.append(d)
# Out:
# https://pythonizing.github.io/data/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=0.html
# https://pythonizing.github.io/data/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=10.html
# https://pythonizing.github.io/data/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=20.html

# %%
import pandas
df=pandas.DataFrame(l)
df
# Out:
#                           Address                     Locality  Beds   Area  \
# 0                       0 Gateway       Rock Springs, WY 82901  None   None
# 1           1003 Winchester Blvd.       Rock Springs, WY 82901     4   None
# 2                   600 Talladega       Rock Springs, WY 82901     5  3,154
# 3              3239 Spearhead Way       Rock Springs, WY 82901     4  3,076
# 4              522 Emerald Street       Rock Springs, WY 82901     3  1,172
# 5            1302 Veteran's Drive       Rock Springs, WY 82901     4  1,932
# 6                1021 Cypress Cir       Rock Springs, WY 82901     4  1,676
# 7                  913 Madison Dr       Rock Springs, WY 82901     3  1,344
# 8               1344 Teton Street       Rock Springs, WY 82901     3  1,920
# 9                  4 Minnies Lane       Rock Springs, WY 82901     3  1,664
# 10                  9339 Sd 26900        Rocksprings, TX 78880  None  2,560
# 11               RR674P13 Hwy 377        Rocksprings, TX 78880  None  2,000
# 12                       0 Hwy 41        Rocksprings, TX 78880  None   None
# 13                  9339 Sd 26900        Rocksprings, TX 78880  None  2,560
# 14                  CR450 Hwy 377        Rocksprings, TX 78880  None   None
# 15                  Cr 240 Cr 240        Rocksprings, TX 78880  None  1,398
# 16                  RR674 Hwy 377        Rocksprings, TX 78880  None  1,738
# 17                 9770a Sd 26900        Rocksprings, TX 78880  None  1,080
# 18                  Lot17 CR 2630        Rocksprings, TX 78880  None   None
# 19                 Tr12,16 CR 520        Rocksprings, TX 78880  None   None
# 20   32575 S Shadow Mountain Road  Black Canyon City, AZ 85324     3  2,318
# 21        32750 S Shangrila Drive  Black Canyon City, AZ 85324     3  2,120
# 22      0000 Black Canyon Highway  Black Canyon City, AZ 85324  None   None
# 23           34775 S CHOLLA Drive  Black Canyon City, AZ 85324     3  1,220
# 24      33403 S. HA-WA-SI TERRACE  BLACK CANYON CITY, AZ 85324     4  2,000
# 25          34263 S Bertha Street  Black Canyon City, AZ 85324     5  2,260
# 26            33160 S Canyon Road  Black Canyon City, AZ 85324     3  1,248
# 27        19421 E Todd Evans Road  Black Canyon City, AZ 85324     3  1,404
# 28             18688 E AGUA Vista  Black Canyon City, AZ 85324  None   None
# 29  50600 N Old Black Canyon Road  Black Canyon City, AZ 85324  None   None
# 30      20101 E SQUAW VALLEY Road  Black Canyon City, AZ 85324  None   None
# 31            33259 S Canyon Road  Black Canyon City, AZ 85324     3  1,056
# 32          34558 S ROADRUNNER RD  Black Canyon City, AZ 85324     2    784
# 33       19260 E Scenic Loop Road  Black Canyon City, AZ 85324  None   None
# 34           19000 E MAREN Avenue  Black Canyon City, AZ 85324  None   None
# 35          19350 E SAGUARO Drive  Black Canyon City, AZ 85324  None   None
# 36         20650 E Amethyst Place  Black Canyon City, AZ 85324  None   None
#
#    Full Bath Half Bath       Price          Lot Size
# 0       None      None    $725,000               NaN
# 1          4      None    $452,900        0.21 Acres
# 2          3      None    $396,900               NaN
# 3          3         1    $389,900  Under 1/2 Acre,
# 4          3      None    $254,000  Under 1/2 Acre,
# 5          2      None    $252,900        0.27 Acres
# 6          3      None    $210,000  Under 1/2 Acre,
# 7          2      None    $209,000  Under 1/2 Acre,
# 8          2      None    $199,900  Under 1/2 Acre,
# 9          2      None    $196,900        2.02 Acres
# 10      None      None  $1,700,000               NaN
# 11      None      None  $1,100,000               NaN
# 12      None      None  $1,080,000               NaN
# 13      None      None    $908,350               NaN
# 14      None      None    $905,000               NaN
# 15      None      None    $695,000               NaN
# 16      None      None    $605,000               NaN
# 17      None      None    $559,805               NaN
# 18      None      None    $504,000               NaN
# 19      None      None    $410,000               NaN
# 20         2      None    $299,900               NaN
# 21         2      None    $167,500               NaN
# 22      None      None    $150,000           5 Acres
# 23         2      None    $129,500               NaN
# 24         2      None    $129,000               NaN
# 25         2      None     $80,000               NaN
# 26         2      None     $77,900               NaN
# 27         2      None     $70,500               NaN
# 28      None      None     $70,000         0.7 Acres
# 29      None      None     $67,500           3 Acres
# 30      None      None     $54,900               NaN
# 31         1      None     $45,600               NaN
# 32         1      None     $40,000    Under 1/2 Acre
# 33      None      None     $30,000        2.35 Acres
# 34      None      None     $29,000        2.05 Acres
# 35      None      None     $28,995        0.73 Acres
# 36      None      None     $15,000        0.31 Acres

# %%
df.to_csv("Output.csv")
